# %%
import csv
index_sh_path = "/home/fanghz/project/TradeDataCache/mdl_4_6_0.csv";
index_sz_path = "/home/fanghz/project/TradeDataCache/mdl_6_29_0.csv";

time_sig = []
cursor = ""
with open(index_sh_path, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    next(reader)
    for row in reader:
        if row[0] != cursor:
            time_sig.append(row[0])
            cursor = row[0]

# %%
time_sig[:100]
# Out:
# ['08:45:06.000',
#  '08:45:12.000',
#  '08:45:15.000',
#  '08:45:18.000',
#  '08:45:24.000',
#  '08:45:27.000',
#  '08:45:30.000',
#  '08:45:36.000',
#  '08:45:42.000',
#  '08:45:48.000',
#  '08:45:51.000',
#  '08:45:54.000',
#  '08:46:00.000',
#  '08:46:06.000',
#  '08:46:12.000',
#  '08:46:18.000',
#  '08:46:21.000',
#  '08:46:24.000',
#  '08:46:30.000',
#  '08:46:33.000',
#  '08:46:36.000',
#  '08:46:39.000',
#  '08:46:42.000',
#  '08:46:48.000',
#  '08:46:51.000',
#  '08:46:54.000',
#  '08:46:57.000',
#  '08:47:00.000',
#  '08:47:06.000',
#  '08:47:12.000',
#  '08:47:18.000',
#  '08:47:24.000',
#  '08:47:30.000',
#  '08:47:33.000',
#  '08:47:36.000',
#  '08:47:39.000',
#  '08:47:42.000',
#  '08:47:45.000',
#  '08:47:48.000',
#  '08:47:54.000',
#  '08:48:00.000',
#  '08:48:03.000',
#  '08:48:06.000',
#  '08:48:09.000',
#  '08:48:12.000',
#  '08:48:15.000',
#  '08:48:18.000',
#  '08:48:21.000',
#  '08:48:24.000',
#  '08:48:30.000',
#  '08:48:36.000',
#  '08:48:39.000',
# ...
